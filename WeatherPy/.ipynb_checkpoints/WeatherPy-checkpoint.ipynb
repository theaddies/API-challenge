# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"
output_data_file_2 = "../output_data/cities_clean.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
plt.ioff()

# %%
 # Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
#assign list variables to build data table.
City = []
Lat = []
Lng = []
Max_Temp= []
Humidity= []
Cloudiness= []
Wind_Speed= []
Country = []
Date = []

# %%
cities
# Out:
# ['hobart',
#  'richards bay',
#  'bredasdorp',
#  'qaqortoq',
#  'mount isa',
#  'puerto maldonado',
#  'chuy',
#  'saleaula',
#  'butaritari',
#  'gurupa',
#  'korla',
#  'dikson',
#  'mataura',
#  'necochea',
#  'port hedland',
#  'tsihombe',
#  'san patricio',
#  'vaini',
#  'new norfolk',
#  'kruisfontein',
#  'roma',
#  'lompoc',
#  'sovetskiy',
#  'berlevag',
#  'amderma',
#  'belaya gora',
#  'arraial do cabo',
#  'atuona',
#  'meulaboh',
#  'nizhniy odes',
#  'sumbe',
#  'hermanus',
#  'qaanaaq',
#  'dickinson',
#  'rikitea',
#  'laguna',
#  'bilibino',
#  'ostrovnoy',
#  'jerome',
#  'kavaratti',
#  'nanortalik',
#  'taolanaro',
#  'bluff',
#  'codrington',
#  'flinders',
#  'belushya guba',
#  'puerto ayora',
#  'hami',
#  'pevek',
#  'guerrero negro',
#  'hofn',
#  'ushuaia',
#  'busselton',
#  'utiroa',
#  'islamkot',
#  'ajaccio',
#  'mar del plata',
#  'ponta delgada',
#  'torres',
#  'cap malheureux',
#  'brejo',
#  'pangnirtung',
#  'punta arenas',
#  'surt',
#  'muswellbrook',
#  'albany',
#  'marcona',
#  'nikolskoye',
#  'barrow',
#  'souillac',
#  'lavrentiya',
#  'port elizabeth',
#  'kaitangata',
#  'barentsburg',
#  'todos santos',
#  'daru',
#  'cidreira',
#  'gayeri',
#  'batagay-alyta',
#  'westpunt',
#  'hilo',
#  'vila franca do campo',
#  'east london',
#  'ambulu',
#  'belmonte',
#  'lebu',
#  'sucua',
#  'lehi',
#  'avarua',
#  'katsuura',
#  'lorengau',
#  'thompson',
#  'tsabong',
#  'honiara',
#  'hithadhoo',
#  'vaitupu',
#  'carnarvon',
#  'launceston',
#  'chokurdakh',
#  'morant bay',
#  'martapura',
#  'tafresh',
#  'attawapiskat',
#  'lasa',
#  'estelle',
#  'bethel',
#  'kavieng',
#  'garowe',
#  'aketi',
#  'tasiilaq',
#  'narsaq',
#  'komsomolskiy',
#  'taltal',
#  'tautira',
#  'beringovskiy',
#  'san miguel',
#  'alice springs',
#  'husavik',
#  'namibe',
#  'libenge',
#  'cornwall',
#  'tabiauea',
#  'leningradskiy',
#  'balugaon',
#  'villanueva',
#  'yellowknife',
#  'balaipungut',
#  'kodiak',
#  'szczytno',
#  'tulun',
#  'tevaitoa',
#  'nisia floresta',
#  'banswada',
#  'sawang daen din',
#  'ilulissat',
#  'kungurtug',
#  'cape town',
#  'aksarka',
#  'broome',
#  'coquimbo',
#  'ribeira grande',
#  'upernavik',
#  'severo-kurilsk',
#  'provideniya',
#  'mikuni',
#  'louisbourg',
#  'kashi',
#  'tiksi',
#  'port blair',
#  'ahipara',
#  'bathsheba',
#  'isangel',
#  'putai',
#  'yumen',
#  'cherskiy',
#  'barcelos',
#  'tuktoyaktuk',
#  'hamilton',
#  'ugoofaaru',
#  'port alfred',
#  'fort nelson',
#  'touros',
#  'salym',
#  'cabo san lucas',
#  'bubaque',
#  'jamestown',
#  'macklin',
#  'saskylakh',
#  'zhigansk',
#  'araouane',
#  'tomatlan',
#  'ust-nera',
#  'loiza',
#  'chlorakas',
#  'suntar',
#  'cayenne',
#  'rengo',
#  'opuwo',
#  'lodwar',
#  'bom jesus',
#  'grindavik',
#  'rungata',
#  'fortuna',
#  'pombia',
#  'kudahuvadhoo',
#  'kapaa',
#  'kyzyl',
#  'talnakh',
#  'longyearbyen',
#  'bolungarvik',
#  'walvis bay',
#  'naze',
#  'teyateyaneng',
#  'puerto narino',
#  'georgetown',
#  'khakhea',
#  'constitucion',
#  'tual',
#  'matagami',
#  'wuwei',
#  'jawhar',
#  'ternate',
#  'sibolga',
#  'nanakuli',
#  'luau',
#  'baryshevo',
#  'kindu',
#  'sentyabrskiy',
#  'half moon bay',
#  'torbay',
#  'oshkosh',
#  'sena madureira',
#  'raymond',
#  'faya',
#  'khatanga',
#  'saint george',
#  'guiglo',
#  'kupang',
#  'dakar',
#  'illoqqortoormiut',
#  'klaksvik',
#  'verkhnyaya inta',
#  'george',
#  'srednekolymsk',
#  'yerbogachen',
#  'champerico',
#  'bambous virieux',
#  'harer',
#  'alta floresta',
#  'samut songkhram',
#  'hays',
#  'san quintin',
#  'yeppoon',
#  'aykhal',
#  'vanavara',
#  'nicoya',
#  'bay roberts',
#  'nelson bay',
#  'tambovka',
#  'tarakan',
#  'gizo',
#  'silver city',
#  'uyuni',
#  'markova',
#  'anloga',
#  'wakefield',
#  'igarka',
#  'pozo colorado',
#  'armacao dos buzios',
#  'viransehir',
#  'mahebourg',
#  'airai',
#  'aklavik',
#  'pundaguitan',
#  'saint-philippe',
#  'ponta do sol',
#  'mys shmidta',
#  'novovasylivka',
#  'umea',
#  'grand river south east',
#  'ken caryl',
#  'milkovo',
#  'caravelas',
#  'pisco',
#  'yulara',
#  'almaznyy',
#  'kununurra',
#  'valparaiso',
#  'marion',
#  'dzhusaly',
#  'malwan',
#  'bonavista',
#  'jabiru',
#  'samusu',
#  'lerwick',
#  'penzance',
#  'gazni',
#  'linguere',
#  'bergen',
#  'norman wells',
#  'kiama',
#  'thinadhoo',
#  'kazachinskoye',
#  'avera',
#  'natchitoches',
#  'togur',
#  'bengkulu',
#  'leshukonskoye',
#  'nemuro',
#  'saldanha',
#  'rio do sul',
#  'dubrovka',
#  'iqaluit',
#  'luderitz',
#  'castro',
#  'yaan',
#  'altay',
#  'ayan',
#  'alofi',
#  'sinnamary',
#  'merauke',
#  'tygda',
#  'shache',
#  'garachine',
#  'arkhara',
#  'kahului',
#  'kutum',
#  'alyangula',
#  'vanimo',
#  'progreso',
#  'frontera',
#  'payo',
#  'smidovich',
#  'grenfell',
#  'fairbanks',
#  'saint-pierre',
#  'halalo',
#  'hailun',
#  'carballo',
#  'aberdeen',
#  'coos bay',
#  'bandarbeyla',
#  'baturaja',
#  'masvingo',
#  'pimenta bueno',
#  'faanui',
#  'geraldton',
#  'monrovia',
#  'warqla',
#  'kantang',
#  'urengoy',
#  'viligili',
#  'galgani',
#  'nome',
#  'saint-joseph',
#  'evensk',
#  'barguzin',
#  'roald',
#  'balkanabat',
#  'svetlaya',
#  'mae sai',
#  'marzuq',
#  'kichera',
#  'maragogi',
#  'guayanilla',
#  'barra do corda',
#  'udachnyy',
#  'kushima',
#  'ancud',
#  'camocim',
#  'thiruvananthapuram',
#  'craig',
#  'dunmore town',
#  'lagoa',
#  'pahrump',
#  'palabuhanratu',
#  'pallisa',
#  'gavrilov-yam',
#  'maumere',
#  'la rioja',
#  'gawler',
#  'katangli',
#  'deputatskiy',
#  'mount gambier',
#  'birjand',
#  'mahadday weyne',
#  'san ramon de la nueva oran',
#  'marsabit',
#  'hasaki',
#  'kharan',
#  'ojinaga',
#  'jamuria',
#  'mingaora',
#  'rabaul',
#  'sao filipe',
#  'asfi',
#  'sao geraldo do araguaia',
#  'poya',
#  'lexington',
#  'huicheng',
#  'cabedelo',
#  'miles city',
#  'labuhan',
#  'les cayes',
#  'flers',
#  'rio gallegos',
#  'saquena',
#  'dicabisagan',
#  'berdigestyakh',
#  'karaul',
#  'namatanai',
#  'porecatu',
#  'fonte boa',
#  'muros',
#  'dongsheng',
#  'burnie',
#  'zaysan',
#  'atasu',
#  'salalah',
#  'mogadishu',
#  'port lincoln',
#  'tafo',
#  'terrace',
#  'zunheboto',
#  'victoria',
#  'esperance',
#  'tigil',
#  'borovoy',
#  'sorong',
#  'mangrol',
#  'sanchez',
#  'jardim',
#  'quatre cocos',
#  'worland',
#  'jiddah',
#  'meyungs',
#  'haines junction',
#  'floro',
#  'bolshiye uki',
#  'yithion',
#  'bajil',
#  'huilong',
#  'adrar',
#  'pacific grove',
#  'nizhnekamsk',
#  'liminangcong',
#  'paragominas',
#  'new ulm',
#  'bargal',
#  'along',
#  'vardo',
#  'impfondo',
#  'baft',
#  'nardaran',
#  'inta',
#  'te anau',
#  'el faiyum',
#  'boende',
#  'albert',
#  'hambantota',
#  'katsina',
#  'tsiroanomandidy',
#  'awbari',
#  'broken hill',
#  'huarmey',
#  'macherla',
#  'vila velha',
#  'calabozo',
#  'milingimbi',
#  'swan hill',
#  'mason city',
#  'saint-francois',
#  'pangkalanbuun',
#  'vaasa',
#  'samarai',
#  'state college',
#  'kwidzyn',
#  'bardiyah',
#  'lima',
#  'palasa',
#  'yong peng',
#  'elesbao veloso',
#  'uhlove',
#  'harper',
#  'whitianga',
#  'sao joao da barra',
#  'patrocinio',
#  'grand-lahou',
#  'mezen',
#  'jian',
#  'dunedin',
#  'eirunepe',
#  'tirumullaivasal',
#  'lamtah',
#  'vostok',
#  'molteno',
#  'dolbeau',
#  'alotau',
#  'burgeo',
#  'dingwall',
#  'albina',
#  'chiang klang',
#  'ixtapa',
#  'sogne',
#  'westport',
#  'miedzyrzecz',
#  'soyo',
#  'grand gaube',
#  'springfield',
#  'olinda',
#  'tilichiki',
#  'srandakan',
#  'kostomuksha',
#  'gushikawa',
#  'portland',
#  'boddam',
#  'karratha',
#  'isabela',
#  'shimoda',
#  'khandyga',
#  'petropavlovka',
#  'asau',
#  'puerto baquerizo moreno',
#  'wawa',
#  'saran',
#  'waipawa',
#  'zhongshan',
#  'camargo',
#  'havre-saint-pierre',
#  'dauphin',
#  'galle',
#  'mayo',
#  'svetlogorsk',
#  'brodnica',
#  'kamaishi',
#  'makakilo city',
#  'luganville',
#  'tuatapere',
#  'abnub',
#  'beloha',
#  'sanbu',
#  'pangai',
#  'cabra',
#  'zhanakorgan',
#  'oksfjord',
#  'moba',
#  'celestun',
#  'sitka',
#  'atocha',
#  'roebourne',
#  'jurm',
#  'teya',
#  'lisala',
#  'acapulco',
#  'kifri',
#  'mareeba',
#  'quepem',
#  'coahuayana',
#  'madras',
#  'am timan',
#  'inirida',
#  'cabras',
#  'makat',
#  'gribanovskiy',
#  'alta',
#  'nouadhibou',
#  'carbonia',
#  'port hardy',
#  'skalistyy',
#  'kalmunai',
#  'amazar',
#  'zhanaozen',
#  'kimparana',
#  'teknaf',
#  'parabel',
#  'ahuimanu',
#  'dhidhdhoo',
#  'kathu',
#  'erzin',
#  'kwinana',
#  'bibbiena',
#  'xuddur',
#  'petauke',
#  'kargasok',
#  'beni',
#  'lafiagi',
#  'dehloran',
#  'chake chake',
#  'baykalsk',
#  'duyure',
#  'cobourg',
#  'japura',
#  'havlickuv brod',
#  'cockburn town',
#  'lincoln',
#  'robertsport',
#  'cutervo',
#  'iranshahr',
#  'pemba',
#  'saraza',
#  'napanee',
#  'palmeirais',
#  'nanlong',
#  'jieshi',
#  'tidore',
#  'toliary',
#  'cam ranh',
#  'khuzhir',
#  'lilongwe',
#  'inverell',
#  'waddan',
#  'marawi',
#  'ithaki',
#  'antofagasta',
#  'oktyabrskoye',
#  'tabuk',
#  'nizhneyansk',
#  'ransang',
#  'college',
#  'cravo norte',
#  'kamina',
#  'kushiro',
#  'jaisalmer',
#  'vuktyl',
#  'rockland',
#  'buford',
#  'wesselsbron',
#  'elko',
#  'coihaique',
#  'saint cloud',
#  'labrea',
#  'ullapool',
#  'grimshaw',
#  'kaoma']

# %%
#cities = ['new norfolk', 'barrow', 'barentsburg', 'staromaryevka', 'thompson', 'yumen', 'bathsheba',\
# 'ushuaia', 'yar-sale', 'nishihara', 'leningradskiy', 'iqaluit', 'severo-kurilsk']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
group_item_number = np.uint8(5)
i = np.uint8(0)
j = np.uint8(0)
item = np.uint16(0)
if len(cities)%group_item_number:
    group_number = int(len(cities) / group_item_number) + 1
else:
    group_number = len(cities) / group_item_number

for i in range(0, group_number):
    j=0
    while ((j < group_item_number) & (item < (len(cities)-1))):

        item = i * (group_item_number) + j
        city = cities[item]
        print(f'Processing record {item} of group {i} item {j} | {city}')
        try:
            response = requests.get(query_url + city).json()
            #City.append()
            Lat.append(response['coord']['lat'])
            Lng.append(response['coord']['lon'])
            Max_Temp.append(response['main']['temp_max'])
            Humidity.append(response['main']['humidity'])
            Cloudiness.append(response['clouds']['all'])
            Wind_Speed.append(response['wind']['speed'])
            Country.append(response['sys']['country'])
            Date.append(response['dt'])
        except KeyError:
            print('Data for ',city,' not available.  Skipping......')
            Lat.append(np.nan)
            Lng.append(np.nan)
            Max_Temp.append(np.nan)
            Humidity.append(np.nan)
            Cloudiness.append(np.nan)
            Wind_Speed.append(np.nan)
            Country.append(np.nan)
            Date.append(np.nan)
        j = j + 1
# Out:
# Processing record 0 of group 0 item 0 | hobart
# Processing record 1 of group 0 item 1 | richards bay
# Processing record 2 of group 0 item 2 | bredasdorp
# Processing record 3 of group 0 item 3 | qaqortoq
# Processing record 4 of group 0 item 4 | mount isa
# Processing record 5 of group 1 item 0 | puerto maldonado
# Processing record 6 of group 1 item 1 | chuy
# Processing record 7 of group 1 item 2 | saleaula
# Data for  saleaula  not available.  Skipping......
# Processing record 8 of group 1 item 3 | butaritari
# Processing record 9 of group 1 item 4 | gurupa
# Processing record 10 of group 2 item 0 | korla
# Processing record 11 of group 2 item 1 | dikson
# Processing record 12 of group 2 item 2 | mataura
# Processing record 13 of group 2 item 3 | necochea
# Processing record 14 of group 2 item 4 | port hedland
# Processing record 15 of group 3 item 0 | tsihombe
# Data for  tsihombe  not available.  Skipping......
# Processing record 16 of group 3 item 1 | san patricio
# Processing record 17 of group 3 item 2 | vaini
# Processing record 18 of group 3 item 3 | new norfolk
# Processing record 19 of group 3 item 4 | kruisfontein
# Processing record 20 of group 4 item 0 | roma
# Processing record 21 of group 4 item 1 | lompoc
# Processing record 22 of group 4 item 2 | sovetskiy
# Processing record 23 of group 4 item 3 | berlevag
# Processing record 24 of group 4 item 4 | amderma
# Data for  amderma  not available.  Skipping......
# Processing record 25 of group 5 item 0 | belaya gora
# Processing record 26 of group 5 item 1 | arraial do cabo
# Processing record 27 of group 5 item 2 | atuona
# Processing record 28 of group 5 item 3 | meulaboh
# Processing record 29 of group 5 item 4 | nizhniy odes
# Processing record 30 of group 6 item 0 | sumbe
# Processing record 31 of group 6 item 1 | hermanus
# Processing record 32 of group 6 item 2 | qaanaaq
# Processing record 33 of group 6 item 3 | dickinson
# Processing record 34 of group 6 item 4 | rikitea
# Processing record 35 of group 7 item 0 | laguna
# Processing record 36 of group 7 item 1 | bilibino
# Processing record 37 of group 7 item 2 | ostrovnoy
# Processing record 38 of group 7 item 3 | jerome
# Processing record 39 of group 7 item 4 | kavaratti
# Processing record 40 of group 8 item 0 | nanortalik
# Processing record 41 of group 8 item 1 | taolanaro
# Data for  taolanaro  not available.  Skipping......
# Processing record 42 of group 8 item 2 | bluff
# Processing record 43 of group 8 item 3 | codrington
# Processing record 44 of group 8 item 4 | flinders
# Processing record 45 of group 9 item 0 | belushya guba
# Data for  belushya guba  not available.  Skipping......
# Processing record 46 of group 9 item 1 | puerto ayora
# Processing record 47 of group 9 item 2 | hami
# Processing record 48 of group 9 item 3 | pevek
# Processing record 49 of group 9 item 4 | guerrero negro
# Processing record 50 of group 10 item 0 | hofn
# Processing record 51 of group 10 item 1 | ushuaia
# Processing record 52 of group 10 item 2 | busselton
# Processing record 53 of group 10 item 3 | utiroa
# Data for  utiroa  not available.  Skipping......
# Processing record 54 of group 10 item 4 | islamkot
# Processing record 55 of group 11 item 0 | ajaccio
# Processing record 56 of group 11 item 1 | mar del plata
# Processing record 57 of group 11 item 2 | ponta delgada
# Processing record 58 of group 11 item 3 | torres
# Processing record 59 of group 11 item 4 | cap malheureux
# Processing record 60 of group 12 item 0 | brejo
# Processing record 61 of group 12 item 1 | pangnirtung
# Processing record 62 of group 12 item 2 | punta arenas
# Processing record 63 of group 12 item 3 | surt
# Processing record 64 of group 12 item 4 | muswellbrook
# Processing record 65 of group 13 item 0 | albany
# Processing record 66 of group 13 item 1 | marcona
# Data for  marcona  not available.  Skipping......
# Processing record 67 of group 13 item 2 | nikolskoye
# Processing record 68 of group 13 item 3 | barrow
# Processing record 69 of group 13 item 4 | souillac
# Processing record 70 of group 14 item 0 | lavrentiya
# Processing record 71 of group 14 item 1 | port elizabeth
# Processing record 72 of group 14 item 2 | kaitangata
# Processing record 73 of group 14 item 3 | barentsburg
# Data for  barentsburg  not available.  Skipping......
# Processing record 74 of group 14 item 4 | todos santos
# Processing record 75 of group 15 item 0 | daru
# Processing record 76 of group 15 item 1 | cidreira
# Processing record 77 of group 15 item 2 | gayeri
# Processing record 78 of group 15 item 3 | batagay-alyta
# Processing record 79 of group 15 item 4 | westpunt
# Data for  westpunt  not available.  Skipping......
# Processing record 80 of group 16 item 0 | hilo
# Processing record 81 of group 16 item 1 | vila franca do campo
# Processing record 82 of group 16 item 2 | east london
# Processing record 83 of group 16 item 3 | ambulu
# Processing record 84 of group 16 item 4 | belmonte
# Processing record 85 of group 17 item 0 | lebu
# Processing record 86 of group 17 item 1 | sucua
# Processing record 87 of group 17 item 2 | lehi
# Processing record 88 of group 17 item 3 | avarua
# Processing record 89 of group 17 item 4 | katsuura
# Processing record 90 of group 18 item 0 | lorengau
# Processing record 91 of group 18 item 1 | thompson
# Processing record 92 of group 18 item 2 | tsabong
# Processing record 93 of group 18 item 3 | honiara
# Processing record 94 of group 18 item 4 | hithadhoo
# Processing record 95 of group 19 item 0 | vaitupu
# Data for  vaitupu  not available.  Skipping......
# Processing record 96 of group 19 item 1 | carnarvon
# Processing record 97 of group 19 item 2 | launceston
# Processing record 98 of group 19 item 3 | chokurdakh
# Processing record 99 of group 19 item 4 | morant bay
# Processing record 100 of group 20 item 0 | martapura
# Processing record 101 of group 20 item 1 | tafresh
# Processing record 102 of group 20 item 2 | attawapiskat
# Data for  attawapiskat  not available.  Skipping......
# Processing record 103 of group 20 item 3 | lasa
# Processing record 104 of group 20 item 4 | estelle
# Processing record 105 of group 21 item 0 | bethel
# Processing record 106 of group 21 item 1 | kavieng
# Processing record 107 of group 21 item 2 | garowe
# Processing record 108 of group 21 item 3 | aketi
# Processing record 109 of group 21 item 4 | tasiilaq
# Processing record 110 of group 22 item 0 | narsaq
# Processing record 111 of group 22 item 1 | komsomolskiy
# Processing record 112 of group 22 item 2 | taltal
# Processing record 113 of group 22 item 3 | tautira
# Processing record 114 of group 22 item 4 | beringovskiy
# Processing record 115 of group 23 item 0 | san miguel
# Processing record 116 of group 23 item 1 | alice springs
# Processing record 117 of group 23 item 2 | husavik
# Processing record 118 of group 23 item 3 | namibe
# Processing record 119 of group 23 item 4 | libenge
# Processing record 120 of group 24 item 0 | cornwall
# Processing record 121 of group 24 item 1 | tabiauea
# Data for  tabiauea  not available.  Skipping......
# Processing record 122 of group 24 item 2 | leningradskiy
# Processing record 123 of group 24 item 3 | balugaon
# Processing record 124 of group 24 item 4 | villanueva
# Processing record 125 of group 25 item 0 | yellowknife
# Processing record 126 of group 25 item 1 | balaipungut
# Processing record 127 of group 25 item 2 | kodiak
# Processing record 128 of group 25 item 3 | szczytno
# Processing record 129 of group 25 item 4 | tulun
# Processing record 130 of group 26 item 0 | tevaitoa
# Processing record 131 of group 26 item 1 | nisia floresta
# Processing record 132 of group 26 item 2 | banswada
# Processing record 133 of group 26 item 3 | sawang daen din
# Processing record 134 of group 26 item 4 | ilulissat
# Processing record 135 of group 27 item 0 | kungurtug
# Processing record 136 of group 27 item 1 | cape town
# Processing record 137 of group 27 item 2 | aksarka
# Processing record 138 of group 27 item 3 | broome
# Processing record 139 of group 27 item 4 | coquimbo
# Processing record 140 of group 28 item 0 | ribeira grande
# Processing record 141 of group 28 item 1 | upernavik
# Processing record 142 of group 28 item 2 | severo-kurilsk
# Processing record 143 of group 28 item 3 | provideniya
# Processing record 144 of group 28 item 4 | mikuni
# Processing record 145 of group 29 item 0 | louisbourg
# Data for  louisbourg  not available.  Skipping......
# Processing record 146 of group 29 item 1 | kashi
# Processing record 147 of group 29 item 2 | tiksi
# Processing record 148 of group 29 item 3 | port blair
# Processing record 149 of group 29 item 4 | ahipara
# Processing record 150 of group 30 item 0 | bathsheba
# Processing record 151 of group 30 item 1 | isangel
# Processing record 152 of group 30 item 2 | putai
# Processing record 153 of group 30 item 3 | yumen
# Processing record 154 of group 30 item 4 | cherskiy
# Processing record 155 of group 31 item 0 | barcelos
# Processing record 156 of group 31 item 1 | tuktoyaktuk
# Processing record 157 of group 31 item 2 | hamilton
# Processing record 158 of group 31 item 3 | ugoofaaru
# Processing record 159 of group 31 item 4 | port alfred
# Processing record 160 of group 32 item 0 | fort nelson
# Processing record 161 of group 32 item 1 | touros
# Processing record 162 of group 32 item 2 | salym
# Processing record 163 of group 32 item 3 | cabo san lucas
# Processing record 164 of group 32 item 4 | bubaque
# Processing record 165 of group 33 item 0 | jamestown
# Processing record 166 of group 33 item 1 | macklin
# Processing record 167 of group 33 item 2 | saskylakh
# Processing record 168 of group 33 item 3 | zhigansk
# Processing record 169 of group 33 item 4 | araouane
# Processing record 170 of group 34 item 0 | tomatlan
# Processing record 171 of group 34 item 1 | ust-nera
# Processing record 172 of group 34 item 2 | loiza
# Processing record 173 of group 34 item 3 | chlorakas
# Processing record 174 of group 34 item 4 | suntar
# Processing record 175 of group 35 item 0 | cayenne
# Processing record 176 of group 35 item 1 | rengo
# Processing record 177 of group 35 item 2 | opuwo
# Processing record 178 of group 35 item 3 | lodwar
# Processing record 179 of group 35 item 4 | bom jesus
# Processing record 180 of group 36 item 0 | grindavik
# Processing record 181 of group 36 item 1 | rungata
# Data for  rungata  not available.  Skipping......
# Processing record 182 of group 36 item 2 | fortuna
# Processing record 183 of group 36 item 3 | pombia
# Processing record 184 of group 36 item 4 | kudahuvadhoo
# Processing record 185 of group 37 item 0 | kapaa
# Processing record 186 of group 37 item 1 | kyzyl
# Processing record 187 of group 37 item 2 | talnakh
# Processing record 188 of group 37 item 3 | longyearbyen
# Processing record 189 of group 37 item 4 | bolungarvik
# Data for  bolungarvik  not available.  Skipping......
# Processing record 190 of group 38 item 0 | walvis bay
# Processing record 191 of group 38 item 1 | naze
# Processing record 192 of group 38 item 2 | teyateyaneng
# Processing record 193 of group 38 item 3 | puerto narino
# Processing record 194 of group 38 item 4 | georgetown
# Processing record 195 of group 39 item 0 | khakhea
# Processing record 196 of group 39 item 1 | constitucion
# Processing record 197 of group 39 item 2 | tual
# Processing record 198 of group 39 item 3 | matagami
# Processing record 199 of group 39 item 4 | wuwei
# Processing record 200 of group 40 item 0 | jawhar
# Processing record 201 of group 40 item 1 | ternate
# Processing record 202 of group 40 item 2 | sibolga
# Processing record 203 of group 40 item 3 | nanakuli
# Processing record 204 of group 40 item 4 | luau
# Processing record 205 of group 41 item 0 | baryshevo
# Processing record 206 of group 41 item 1 | kindu
# Processing record 207 of group 41 item 2 | sentyabrskiy
# Data for  sentyabrskiy  not available.  Skipping......
# Processing record 208 of group 41 item 3 | half moon bay
# Processing record 209 of group 41 item 4 | torbay
# Processing record 210 of group 42 item 0 | oshkosh
# Processing record 211 of group 42 item 1 | sena madureira
# Processing record 212 of group 42 item 2 | raymond
# Processing record 213 of group 42 item 3 | faya
# Processing record 214 of group 42 item 4 | khatanga
# Processing record 215 of group 43 item 0 | saint george
# Processing record 216 of group 43 item 1 | guiglo
# Processing record 217 of group 43 item 2 | kupang
# Processing record 218 of group 43 item 3 | dakar
# Processing record 219 of group 43 item 4 | illoqqortoormiut
# Data for  illoqqortoormiut  not available.  Skipping......
# Processing record 220 of group 44 item 0 | klaksvik
# Processing record 221 of group 44 item 1 | verkhnyaya inta
# Processing record 222 of group 44 item 2 | george
# Processing record 223 of group 44 item 3 | srednekolymsk
# Processing record 224 of group 44 item 4 | yerbogachen
# Processing record 225 of group 45 item 0 | champerico
# Processing record 226 of group 45 item 1 | bambous virieux
# Processing record 227 of group 45 item 2 | harer
# Processing record 228 of group 45 item 3 | alta floresta
# Processing record 229 of group 45 item 4 | samut songkhram
# Processing record 230 of group 46 item 0 | hays
# Processing record 231 of group 46 item 1 | san quintin
# Processing record 232 of group 46 item 2 | yeppoon
# Processing record 233 of group 46 item 3 | aykhal
# Processing record 234 of group 46 item 4 | vanavara
# Processing record 235 of group 47 item 0 | nicoya
# Processing record 236 of group 47 item 1 | bay roberts
# Processing record 237 of group 47 item 2 | nelson bay
# Processing record 238 of group 47 item 3 | tambovka
# Processing record 239 of group 47 item 4 | tarakan
# Processing record 240 of group 48 item 0 | gizo
# Processing record 241 of group 48 item 1 | silver city
# Processing record 242 of group 48 item 2 | uyuni
# Processing record 243 of group 48 item 3 | markova
# Processing record 244 of group 48 item 4 | anloga
# Processing record 245 of group 49 item 0 | wakefield
# Processing record 246 of group 49 item 1 | igarka
# Processing record 247 of group 49 item 2 | pozo colorado
# Processing record 248 of group 49 item 3 | armacao dos buzios
# Data for  armacao dos buzios  not available.  Skipping......
# Processing record 249 of group 49 item 4 | viransehir
# Processing record 250 of group 50 item 0 | mahebourg
# Processing record 251 of group 50 item 1 | airai
# Processing record 252 of group 50 item 2 | aklavik
# Processing record 253 of group 50 item 3 | pundaguitan
# Processing record 254 of group 50 item 4 | saint-philippe
# Processing record 255 of group 51 item 0 | ponta do sol
# Processing record 256 of group 51 item 1 | mys shmidta
# Data for  mys shmidta  not available.  Skipping......
# Processing record 257 of group 51 item 2 | novovasylivka
# Processing record 258 of group 51 item 3 | umea
# Processing record 259 of group 51 item 4 | grand river south east
# Data for  grand river south east  not available.  Skipping......
# Processing record 260 of group 52 item 0 | ken caryl
# Processing record 261 of group 52 item 1 | milkovo
# Processing record 262 of group 52 item 2 | caravelas
# Processing record 263 of group 52 item 3 | pisco
# Processing record 264 of group 52 item 4 | yulara
# Processing record 265 of group 53 item 0 | almaznyy
# Processing record 266 of group 53 item 1 | kununurra
# Processing record 267 of group 53 item 2 | valparaiso
# Processing record 268 of group 53 item 3 | marion
# Processing record 269 of group 53 item 4 | dzhusaly
# Data for  dzhusaly  not available.  Skipping......
# Processing record 270 of group 54 item 0 | malwan
# Data for  malwan  not available.  Skipping......
# Processing record 271 of group 54 item 1 | bonavista
# Processing record 272 of group 54 item 2 | jabiru
# Data for  jabiru  not available.  Skipping......
# Processing record 273 of group 54 item 3 | samusu
# Data for  samusu  not available.  Skipping......
# Processing record 274 of group 54 item 4 | lerwick
# Processing record 275 of group 55 item 0 | penzance
# Processing record 276 of group 55 item 1 | gazni
# Data for  gazni  not available.  Skipping......
# Processing record 277 of group 55 item 2 | linguere
# Processing record 278 of group 55 item 3 | bergen
# Processing record 279 of group 55 item 4 | norman wells
# Processing record 280 of group 56 item 0 | kiama
# Processing record 281 of group 56 item 1 | thinadhoo
# Processing record 282 of group 56 item 2 | kazachinskoye
# Processing record 283 of group 56 item 3 | avera
# Processing record 284 of group 56 item 4 | natchitoches
# Processing record 285 of group 57 item 0 | togur
# Processing record 286 of group 57 item 1 | bengkulu
# Processing record 287 of group 57 item 2 | leshukonskoye
# Processing record 288 of group 57 item 3 | nemuro
# Processing record 289 of group 57 item 4 | saldanha
# Processing record 290 of group 58 item 0 | rio do sul
# Processing record 291 of group 58 item 1 | dubrovka
# Processing record 292 of group 58 item 2 | iqaluit
# Processing record 293 of group 58 item 3 | luderitz
# Processing record 294 of group 58 item 4 | castro
# Processing record 295 of group 59 item 0 | yaan
# Processing record 296 of group 59 item 1 | altay
# Processing record 297 of group 59 item 2 | ayan
# Processing record 298 of group 59 item 3 | alofi
# Processing record 299 of group 59 item 4 | sinnamary
# Processing record 300 of group 60 item 0 | merauke
# Processing record 301 of group 60 item 1 | tygda
# Processing record 302 of group 60 item 2 | shache
# Processing record 303 of group 60 item 3 | garachine
# Processing record 304 of group 60 item 4 | arkhara
# Processing record 305 of group 61 item 0 | kahului
# Processing record 306 of group 61 item 1 | kutum
# Processing record 307 of group 61 item 2 | alyangula
# Processing record 308 of group 61 item 3 | vanimo
# Processing record 309 of group 61 item 4 | progreso
# Processing record 310 of group 62 item 0 | frontera
# Processing record 311 of group 62 item 1 | payo
# Processing record 312 of group 62 item 2 | smidovich
# Processing record 313 of group 62 item 3 | grenfell
# Processing record 314 of group 62 item 4 | fairbanks
# Processing record 315 of group 63 item 0 | saint-pierre
# Processing record 316 of group 63 item 1 | halalo
# Data for  halalo  not available.  Skipping......
# Processing record 317 of group 63 item 2 | hailun
# Processing record 318 of group 63 item 3 | carballo
# Processing record 319 of group 63 item 4 | aberdeen
# Processing record 320 of group 64 item 0 | coos bay
# Processing record 321 of group 64 item 1 | bandarbeyla
# Processing record 322 of group 64 item 2 | baturaja
# Processing record 323 of group 64 item 3 | masvingo
# Processing record 324 of group 64 item 4 | pimenta bueno
# Processing record 325 of group 65 item 0 | faanui
# Processing record 326 of group 65 item 1 | geraldton
# Processing record 327 of group 65 item 2 | monrovia
# Processing record 328 of group 65 item 3 | warqla
# Data for  warqla  not available.  Skipping......
# Processing record 329 of group 65 item 4 | kantang
# Processing record 330 of group 66 item 0 | urengoy
# Processing record 331 of group 66 item 1 | viligili
# Data for  viligili  not available.  Skipping......
# Processing record 332 of group 66 item 2 | galgani
# Data for  galgani  not available.  Skipping......
# Processing record 333 of group 66 item 3 | nome
# Processing record 334 of group 66 item 4 | saint-joseph
# Processing record 335 of group 67 item 0 | evensk
# Processing record 336 of group 67 item 1 | barguzin
# Processing record 337 of group 67 item 2 | roald
# Processing record 338 of group 67 item 3 | balkanabat
# Processing record 339 of group 67 item 4 | svetlaya
# Processing record 340 of group 68 item 0 | mae sai
# Processing record 341 of group 68 item 1 | marzuq
# Processing record 342 of group 68 item 2 | kichera
# Processing record 343 of group 68 item 3 | maragogi
# Processing record 344 of group 68 item 4 | guayanilla
# Processing record 345 of group 69 item 0 | barra do corda
# Processing record 346 of group 69 item 1 | udachnyy
# Processing record 347 of group 69 item 2 | kushima
# Processing record 348 of group 69 item 3 | ancud
# Processing record 349 of group 69 item 4 | camocim
# Processing record 350 of group 70 item 0 | thiruvananthapuram
# Processing record 351 of group 70 item 1 | craig
# Processing record 352 of group 70 item 2 | dunmore town
# Processing record 353 of group 70 item 3 | lagoa
# Processing record 354 of group 70 item 4 | pahrump
# Processing record 355 of group 71 item 0 | palabuhanratu
# Data for  palabuhanratu  not available.  Skipping......
# Processing record 356 of group 71 item 1 | pallisa
# Processing record 357 of group 71 item 2 | gavrilov-yam
# Processing record 358 of group 71 item 3 | maumere
# Processing record 359 of group 71 item 4 | la rioja
# Processing record 360 of group 72 item 0 | gawler
# Processing record 361 of group 72 item 1 | katangli
# Processing record 362 of group 72 item 2 | deputatskiy
# Processing record 363 of group 72 item 3 | mount gambier
# Processing record 364 of group 72 item 4 | birjand
# Processing record 365 of group 73 item 0 | mahadday weyne
# Data for  mahadday weyne  not available.  Skipping......
# Processing record 366 of group 73 item 1 | san ramon de la nueva oran
# Processing record 367 of group 73 item 2 | marsabit
# Processing record 368 of group 73 item 3 | hasaki
# Processing record 369 of group 73 item 4 | kharan
# Processing record 370 of group 74 item 0 | ojinaga
# Processing record 371 of group 74 item 1 | jamuria
# Processing record 372 of group 74 item 2 | mingaora
# Processing record 373 of group 74 item 3 | rabaul
# Processing record 374 of group 74 item 4 | sao filipe
# Processing record 375 of group 75 item 0 | asfi
# Processing record 376 of group 75 item 1 | sao geraldo do araguaia
# Processing record 377 of group 75 item 2 | poya
# Processing record 378 of group 75 item 3 | lexington
# Processing record 379 of group 75 item 4 | huicheng
# Processing record 380 of group 76 item 0 | cabedelo
# Processing record 381 of group 76 item 1 | miles city
# Processing record 382 of group 76 item 2 | labuhan
# Processing record 383 of group 76 item 3 | les cayes
# Processing record 384 of group 76 item 4 | flers
# Processing record 385 of group 77 item 0 | rio gallegos
# Processing record 386 of group 77 item 1 | saquena
# Processing record 387 of group 77 item 2 | dicabisagan
# Processing record 388 of group 77 item 3 | berdigestyakh
# Processing record 389 of group 77 item 4 | karaul
# Data for  karaul  not available.  Skipping......
# Processing record 390 of group 78 item 0 | namatanai
# Processing record 391 of group 78 item 1 | porecatu
# Processing record 392 of group 78 item 2 | fonte boa
# Processing record 393 of group 78 item 3 | muros
# Processing record 394 of group 78 item 4 | dongsheng
# Processing record 395 of group 79 item 0 | burnie
# Processing record 396 of group 79 item 1 | zaysan
# Processing record 397 of group 79 item 2 | atasu
# Processing record 398 of group 79 item 3 | salalah
# Processing record 399 of group 79 item 4 | mogadishu
# Processing record 400 of group 80 item 0 | port lincoln
# Processing record 401 of group 80 item 1 | tafo
# Processing record 402 of group 80 item 2 | terrace
# Processing record 403 of group 80 item 3 | zunheboto
# Processing record 404 of group 80 item 4 | victoria
# Processing record 405 of group 81 item 0 | esperance
# Processing record 406 of group 81 item 1 | tigil
# Processing record 407 of group 81 item 2 | borovoy
# Processing record 408 of group 81 item 3 | sorong
# Processing record 409 of group 81 item 4 | mangrol
# Processing record 410 of group 82 item 0 | sanchez
# Processing record 411 of group 82 item 1 | jardim
# Processing record 412 of group 82 item 2 | quatre cocos
# Processing record 413 of group 82 item 3 | worland
# Processing record 414 of group 82 item 4 | jiddah
# Data for  jiddah  not available.  Skipping......
# Processing record 415 of group 83 item 0 | meyungs
# Data for  meyungs  not available.  Skipping......
# Processing record 416 of group 83 item 1 | haines junction
# Processing record 417 of group 83 item 2 | floro
# Processing record 418 of group 83 item 3 | bolshiye uki
# Data for  bolshiye uki  not available.  Skipping......
# Processing record 419 of group 83 item 4 | yithion
# Data for  yithion  not available.  Skipping......
# Processing record 420 of group 84 item 0 | bajil
# Processing record 421 of group 84 item 1 | huilong
# Processing record 422 of group 84 item 2 | adrar
# Processing record 423 of group 84 item 3 | pacific grove
# Processing record 424 of group 84 item 4 | nizhnekamsk
# Processing record 425 of group 85 item 0 | liminangcong
# Data for  liminangcong  not available.  Skipping......
# Processing record 426 of group 85 item 1 | paragominas
# Processing record 427 of group 85 item 2 | new ulm
# Processing record 428 of group 85 item 3 | bargal
# Data for  bargal  not available.  Skipping......
# Processing record 429 of group 85 item 4 | along
# Processing record 430 of group 86 item 0 | vardo
# Processing record 431 of group 86 item 1 | impfondo
# Processing record 432 of group 86 item 2 | baft
# Processing record 433 of group 86 item 3 | nardaran
# Processing record 434 of group 86 item 4 | inta
# Processing record 435 of group 87 item 0 | te anau
# Processing record 436 of group 87 item 1 | el faiyum
# Data for  el faiyum  not available.  Skipping......
# Processing record 437 of group 87 item 2 | boende
# Processing record 438 of group 87 item 3 | albert
# Processing record 439 of group 87 item 4 | hambantota
# Processing record 440 of group 88 item 0 | katsina
# Processing record 441 of group 88 item 1 | tsiroanomandidy
# Processing record 442 of group 88 item 2 | awbari
# Processing record 443 of group 88 item 3 | broken hill
# Processing record 444 of group 88 item 4 | huarmey
# Processing record 445 of group 89 item 0 | macherla
# Processing record 446 of group 89 item 1 | vila velha
# Processing record 447 of group 89 item 2 | calabozo
# Processing record 448 of group 89 item 3 | milingimbi
# Data for  milingimbi  not available.  Skipping......
# Processing record 449 of group 89 item 4 | swan hill
# Processing record 450 of group 90 item 0 | mason city
# Processing record 451 of group 90 item 1 | saint-francois
# Processing record 452 of group 90 item 2 | pangkalanbuun
# Processing record 453 of group 90 item 3 | vaasa
# Processing record 454 of group 90 item 4 | samarai
# Processing record 455 of group 91 item 0 | state college
# Processing record 456 of group 91 item 1 | kwidzyn
# Processing record 457 of group 91 item 2 | bardiyah
# Processing record 458 of group 91 item 3 | lima
# Processing record 459 of group 91 item 4 | palasa
# Processing record 460 of group 92 item 0 | yong peng
# Processing record 461 of group 92 item 1 | elesbao veloso
# Processing record 462 of group 92 item 2 | uhlove
# Processing record 463 of group 92 item 3 | harper
# Processing record 464 of group 92 item 4 | whitianga
# Processing record 465 of group 93 item 0 | sao joao da barra
# Processing record 466 of group 93 item 1 | patrocinio
# Processing record 467 of group 93 item 2 | grand-lahou
# Processing record 468 of group 93 item 3 | mezen
# Processing record 469 of group 93 item 4 | jian
# Processing record 470 of group 94 item 0 | dunedin
# Processing record 471 of group 94 item 1 | eirunepe
# Processing record 472 of group 94 item 2 | tirumullaivasal
# Processing record 473 of group 94 item 3 | lamtah
# Processing record 474 of group 94 item 4 | vostok
# Processing record 475 of group 95 item 0 | molteno
# Processing record 476 of group 95 item 1 | dolbeau
# Data for  dolbeau  not available.  Skipping......
# Processing record 477 of group 95 item 2 | alotau
# Data for  alotau  not available.  Skipping......
# Processing record 478 of group 95 item 3 | burgeo
# Processing record 479 of group 95 item 4 | dingwall
# Processing record 480 of group 96 item 0 | albina
# Processing record 481 of group 96 item 1 | chiang klang
# Processing record 482 of group 96 item 2 | ixtapa
# Processing record 483 of group 96 item 3 | sogne
# Processing record 484 of group 96 item 4 | westport
# Processing record 485 of group 97 item 0 | miedzyrzecz
# Processing record 486 of group 97 item 1 | soyo
# Processing record 487 of group 97 item 2 | grand gaube
# Processing record 488 of group 97 item 3 | springfield
# Processing record 489 of group 97 item 4 | olinda
# Processing record 490 of group 98 item 0 | tilichiki
# Processing record 491 of group 98 item 1 | srandakan
# Processing record 492 of group 98 item 2 | kostomuksha
# Processing record 493 of group 98 item 3 | gushikawa
# Processing record 494 of group 98 item 4 | portland
# Processing record 495 of group 99 item 0 | boddam
# Processing record 496 of group 99 item 1 | karratha
# Processing record 497 of group 99 item 2 | isabela
# Processing record 498 of group 99 item 3 | shimoda
# Processing record 499 of group 99 item 4 | khandyga
# Processing record 500 of group 100 item 0 | petropavlovka
# Processing record 501 of group 100 item 1 | asau
# Processing record 502 of group 100 item 2 | puerto baquerizo moreno
# Processing record 503 of group 100 item 3 | wawa
# Processing record 504 of group 100 item 4 | saran
# Processing record 505 of group 101 item 0 | waipawa
# Processing record 506 of group 101 item 1 | zhongshan
# Processing record 507 of group 101 item 2 | camargo
# Processing record 508 of group 101 item 3 | havre-saint-pierre
# Processing record 509 of group 101 item 4 | dauphin
# Processing record 510 of group 102 item 0 | galle
# Processing record 511 of group 102 item 1 | mayo
# Processing record 512 of group 102 item 2 | svetlogorsk
# Processing record 513 of group 102 item 3 | brodnica
# Processing record 514 of group 102 item 4 | kamaishi
# Processing record 515 of group 103 item 0 | makakilo city
# Processing record 516 of group 103 item 1 | luganville
# Processing record 517 of group 103 item 2 | tuatapere
# Processing record 518 of group 103 item 3 | abnub
# Processing record 519 of group 103 item 4 | beloha
# Processing record 520 of group 104 item 0 | sanbu
# Processing record 521 of group 104 item 1 | pangai
# Processing record 522 of group 104 item 2 | cabra
# Processing record 523 of group 104 item 3 | zhanakorgan
# Processing record 524 of group 104 item 4 | oksfjord
# Processing record 525 of group 105 item 0 | moba
# Processing record 526 of group 105 item 1 | celestun
# Processing record 527 of group 105 item 2 | sitka
# Processing record 528 of group 105 item 3 | atocha
# Processing record 529 of group 105 item 4 | roebourne
# Processing record 530 of group 106 item 0 | jurm
# Processing record 531 of group 106 item 1 | teya
# Processing record 532 of group 106 item 2 | lisala
# Processing record 533 of group 106 item 3 | acapulco
# Processing record 534 of group 106 item 4 | kifri
# Processing record 535 of group 107 item 0 | mareeba
# Processing record 536 of group 107 item 1 | quepem
# Processing record 537 of group 107 item 2 | coahuayana
# Processing record 538 of group 107 item 3 | madras
# Processing record 539 of group 107 item 4 | am timan
# Processing record 540 of group 108 item 0 | inirida
# Processing record 541 of group 108 item 1 | cabras
# Processing record 542 of group 108 item 2 | makat
# Processing record 543 of group 108 item 3 | gribanovskiy
# Processing record 544 of group 108 item 4 | alta
# Processing record 545 of group 109 item 0 | nouadhibou
# Processing record 546 of group 109 item 1 | carbonia
# Processing record 547 of group 109 item 2 | port hardy
# Processing record 548 of group 109 item 3 | skalistyy
# Data for  skalistyy  not available.  Skipping......
# Processing record 549 of group 109 item 4 | kalmunai
# Processing record 550 of group 110 item 0 | amazar
# Processing record 551 of group 110 item 1 | zhanaozen
# Processing record 552 of group 110 item 2 | kimparana
# Processing record 553 of group 110 item 3 | teknaf
# Processing record 554 of group 110 item 4 | parabel
# Processing record 555 of group 111 item 0 | ahuimanu
# Processing record 556 of group 111 item 1 | dhidhdhoo
# Processing record 557 of group 111 item 2 | kathu
# Processing record 558 of group 111 item 3 | erzin
# Processing record 559 of group 111 item 4 | kwinana
# Processing record 560 of group 112 item 0 | bibbiena
# Processing record 561 of group 112 item 1 | xuddur
# Processing record 562 of group 112 item 2 | petauke
# Processing record 563 of group 112 item 3 | kargasok
# Processing record 564 of group 112 item 4 | beni
# Processing record 565 of group 113 item 0 | lafiagi
# Processing record 566 of group 113 item 1 | dehloran
# Processing record 567 of group 113 item 2 | chake chake
# Processing record 568 of group 113 item 3 | baykalsk
# Processing record 569 of group 113 item 4 | duyure
# Processing record 570 of group 114 item 0 | cobourg
# Processing record 571 of group 114 item 1 | japura
# Processing record 572 of group 114 item 2 | havlickuv brod
# Processing record 573 of group 114 item 3 | cockburn town
# Processing record 574 of group 114 item 4 | lincoln
# Processing record 575 of group 115 item 0 | robertsport
# Processing record 576 of group 115 item 1 | cutervo
# Processing record 577 of group 115 item 2 | iranshahr
# Processing record 578 of group 115 item 3 | pemba
# Processing record 579 of group 115 item 4 | saraza
# Processing record 580 of group 116 item 0 | napanee
# Processing record 581 of group 116 item 1 | palmeirais
# Processing record 582 of group 116 item 2 | nanlong
# Processing record 583 of group 116 item 3 | jieshi
# Processing record 584 of group 116 item 4 | tidore
# Data for  tidore  not available.  Skipping......
# Processing record 585 of group 117 item 0 | toliary
# Data for  toliary  not available.  Skipping......
# Processing record 586 of group 117 item 1 | cam ranh
# Processing record 587 of group 117 item 2 | khuzhir
# Processing record 588 of group 117 item 3 | lilongwe
# Processing record 589 of group 117 item 4 | inverell
# Processing record 590 of group 118 item 0 | waddan
# Processing record 591 of group 118 item 1 | marawi
# Processing record 592 of group 118 item 2 | ithaki
# Processing record 593 of group 118 item 3 | antofagasta
# Processing record 594 of group 118 item 4 | oktyabrskoye
# Processing record 595 of group 119 item 0 | tabuk
# Processing record 596 of group 119 item 1 | nizhneyansk
# Data for  nizhneyansk  not available.  Skipping......
# Processing record 597 of group 119 item 2 | ransang
# Processing record 598 of group 119 item 3 | college
# Processing record 599 of group 119 item 4 | cravo norte
# Processing record 600 of group 120 item 0 | kamina
# Processing record 601 of group 120 item 1 | kushiro
# Processing record 602 of group 120 item 2 | jaisalmer
# Processing record 603 of group 120 item 3 | vuktyl
# Processing record 604 of group 120 item 4 | rockland
# Processing record 605 of group 121 item 0 | buford
# Processing record 606 of group 121 item 1 | wesselsbron
# Processing record 607 of group 121 item 2 | elko
# Processing record 608 of group 121 item 3 | coihaique
# Processing record 609 of group 121 item 4 | saint cloud
# Processing record 610 of group 122 item 0 | labrea
# Processing record 611 of group 122 item 1 | ullapool
# Processing record 612 of group 122 item 2 | grimshaw
# Processing record 613 of group 122 item 3 | kaoma

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
main_df = pd.DataFrame({'city' : cities, 'Latitude' : Lat, 'Longitude': Lng, "Max temp, F": Max_Temp, "Humidity %" : Humidity, \
            "Cloudiness" : Cloudiness, 'Wind Speed, mph' : Wind_Speed, 'Country' : Country , 'Date' : Date})
len(main_df)
main_df
# Out:
#              city  Latitude  Longitude  Max temp, F  Humidity %  Cloudiness  \
# 0          hobart    -42.88     147.33        55.99        54.0        40.0
# 1    richards bay    -28.78      32.04        68.68        52.0         0.0
# 2      bredasdorp    -34.53      20.04        62.60        63.0        30.0
# 3        qaqortoq     60.72     -46.03        42.80        56.0        75.0
# 4       mount isa    -20.73     139.50        64.40        30.0         0.0
# ..            ...       ...        ...          ...         ...         ...
# 609   saint cloud     45.56     -94.16        66.00        48.0        75.0
# 610        labrea     -7.26     -64.80        78.08        84.0        89.0
# 611      ullapool     57.90      -5.16        70.00        71.0        99.0
# 612      grimshaw     56.18    -117.60        50.00        93.0        90.0
# 613         kaoma    -14.78      24.80        75.36        34.0        23.0
#
#      Wind Speed, mph Country          Date
# 0              12.75      AU  1.592229e+09
# 1               9.86      ZA  1.592229e+09
# 2              10.09      ZA  1.592229e+09
# 3               9.17      GL  1.592229e+09
# 4              11.41      AU  1.592229e+09
# ..               ...     ...           ...
# 609            14.99      US  1.592229e+09
# 610             3.31      BR  1.592229e+09
# 611             8.99      GB  1.592229e+09
# 612             9.17      CA  1.592229e+09
# 613            10.47      ZM  1.592229e+09
#
# [614 rows x 9 columns]

# %%
main_df.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#there are no cities with humidity over 100%
main_df.loc[(main_df['Humidity %'] > 100)][:]
# Out:
# Empty DataFrame
# Columns: [city, Latitude, Longitude, Max temp, F, Humidity %, Cloudiness, Wind Speed, mph, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_index = main_df.loc[(main_df['Humidity %'] > 100)].index
humidity_index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = main_df.drop(index = humidity_index)
clean_city_data
# Out:
#              city  Latitude  Longitude  Max temp, F  Humidity %  Cloudiness  \
# 0          hobart    -42.88     147.33        55.99        54.0        40.0
# 1    richards bay    -28.78      32.04        68.68        52.0         0.0
# 2      bredasdorp    -34.53      20.04        62.60        63.0        30.0
# 3        qaqortoq     60.72     -46.03        42.80        56.0        75.0
# 4       mount isa    -20.73     139.50        64.40        30.0         0.0
# ..            ...       ...        ...          ...         ...         ...
# 609   saint cloud     45.56     -94.16        66.00        48.0        75.0
# 610        labrea     -7.26     -64.80        78.08        84.0        89.0
# 611      ullapool     57.90      -5.16        70.00        71.0        99.0
# 612      grimshaw     56.18    -117.60        50.00        93.0        90.0
# 613         kaoma    -14.78      24.80        75.36        34.0        23.0
#
#      Wind Speed, mph Country          Date
# 0              12.75      AU  1.592229e+09
# 1               9.86      ZA  1.592229e+09
# 2              10.09      ZA  1.592229e+09
# 3               9.17      GL  1.592229e+09
# 4              11.41      AU  1.592229e+09
# ..               ...     ...           ...
# 609            14.99      US  1.592229e+09
# 610             3.31      BR  1.592229e+09
# 611             8.99      GB  1.592229e+09
# 612             9.17      CA  1.592229e+09
# 613            10.47      ZM  1.592229e+09
#
# [614 rows x 9 columns]

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file_2)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
now = datetime.now()
date = now.strftime("%m/%d/%Y")
temperature_title = "Latitude versus Temperature\n"+date
clean_city_data.plot(x = 'Latitude', y = 'Max temp, F', kind='scatter', title = temperature_title)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity_title = "Latitude versus Humidity\n"+date
clean_city_data.plot(x = 'Latitude', y = 'Humidity %', kind='scatter', title = humidity_title)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cloudiness_title = "Latitude versus Cloudiness\n"+date
clean_city_data.plot(x = 'Latitude', y = 'Cloudiness', kind='scatter', title = cloudiness_title)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
wind_speed_title = "Latitude versus Wind Speed\n"+date
clean_city_data.plot(x = 'Latitude', y = 'Wind Speed, mph', kind='scatter', title = wind_speed_title)

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x_values, y_values, graph_title):
    slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
    plt.scatter(x = x_values, y = y_values)
    return

# %%
# Create Northern and Southern Hemisphere DataFrames
#I created a dataframe of dataframes.  One is 'north' and the other 'south'
city_north_df = clean_city_data.loc[clean_city_data['Latitude'] > 0][:]
city_south_df = clean_city_data.loc[clean_city_data['Latitude'] < 0][:]
city_north_df.head()
city_south_df.head()
data_df = {'North' : city_north_df, 'South' : city_south_df}

# %%
hemisphere_list = ['North', 'South']
y_axis_data_list = ['Max temp, F', 'Humidity %', 'Cloudiness', 'Wind Speed, mph']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#this function simply takes in the slope, intercept and max and min latitudes
#it returns the corresponding y_values for plotting
def y_values(slope, intercept, x_max, x_min):
    y_max = slope * x_max + intercept
    y_min = slope * x_min + intercept
    return (y_max, y_min)

# %%
plt.scatter(x = data_df['North']['Latitude'], y = data_df['North']['Max temp, F'])
plt.title('adf')
slope, intercept, r_value, p_value, std_err = linregress(x = data_df['North']['Latitude'], y = data_df['North']['Max temp, F'])
x_max = data_df['North']['Latitude'].max()
x_min = data_df['North']['Latitude'].min()
y_max, y_min = y_values(slope, intercept, x_max, x_min)
print(type(y_values(slope, intercept, x_max, x_min)))
x_line = [x_max, x_min]
y_line = [y_max, y_min]
print(y_max)
plt.plot(x_line, y_line, color = 'red')
text_equation = 'y = {:.2f} * x + {:.2f}'.format(slope, intercept)
plt.text(1, 1,text_equation, color = 'r')
plt.legend(['correlation', 'raw data'] , loc = 'best')
# Out:
# <class 'tuple'>
# 48.62997300786651

# %% [markdown]
# #### Generate all graphs

# %%
def graph_function(hemisphere, y_axis_data):
    plt.figure()
    plt.scatter(x = data_df[hemisphere]['Latitude'], y = data_df[hemisphere][y_axis_data])
    plt.title('{}ern Hemisphere - {} vs. Latitude\n Linear Regression'.format(hemisphere, y_axis_data))
    slope, intercept, r_value, p_value, std_err = linregress(x = data_df[hemisphere]['Latitude'], y = data_df[hemisphere][y_axis_data])
    r_squared = r_value ** 2
    x_max = data_df[hemisphere]['Latitude'].max()
    x_min = data_df[hemisphere]['Latitude'].min()
    y_max, y_min = y_values(slope, intercept, x_max, x_min)
    x_line = [x_max, x_min]
    y_line = [y_max, y_min]
    print(y_max)
    plt.plot(x_line, y_line, color = 'red')
    text_equation = 'y = {:.2f} * x + {:.2f}\nr**2 = {:.4f}'.format(slope, intercept, r_squared)
    plt.text(x_min, y_max,text_equation, color = 'r', bbox=dict(facecolor='w', alpha=0.5))
    plt.legend(['correlation', 'raw data'] , bbox_to_anchor=(1.05, 1), loc = 'upper left')
    #this line is key to making the graphs plot one after another
    plt.show()

# %%
for hemisphere in hemisphere_list:
    for y_axis_data in y_axis_data_list:
        print('y_axis_data_list', y_axis_data)
        graph_function(hemisphere, y_axis_data)
# Out:
# y_axis_data_list Max temp, F
# 48.62997300786651
# y_axis_data_list Humidity %
# 60.9278046507061
# y_axis_data_list Cloudiness
# 52.562226340528134
# y_axis_data_list Wind Speed, mph
# 9.167525852253117
# y_axis_data_list Max temp, F
# 85.17850041126908
# y_axis_data_list Humidity %
# 67.8647184161538
# y_axis_data_list Cloudiness
# 46.13433119758313
# y_axis_data_list Wind Speed, mph
# 8.294203209948103

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
